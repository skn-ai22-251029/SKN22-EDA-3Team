# %% [markdown]
# # EDA (Exploratory Data Analysis) 보고서: 애니메이션 장르-태그 상관관계 분석

# %% [markdown]
# ## 01.
# 중복

# %% [markdown]
# ## 02.
# tag_, genres

# %% [markdown]
# ## 03. 데이터 요약 및 기술 통계 (인기작 중심)
# - `popularity` 기준 상위 작품들의 `genre_`, `tag_` 분포를 파악합니다.
# - **상위 100개,  작품**에서 가장 많이 등장하는 장르와 태그를 확인합니다.

# %% [markdown]
# ## 04. 결측치 및 이상치 점검
# 중복

# %% [markdown]
# ## 05. 변수 분포 시각화 (단변량)
# - 장르와 태그가 전체 데이터에서 얼마나 자주 등장하는지 빈도를 시각화합니다.

# %% [markdown]
# ## 06. 변수 간 관계 시각화 (상관관계 히트맵)
# - 장르와 태그 간의 공통 출현(Co-occurrence) 패턴을 상관계수로 확인합니다.
# - **임계값(Threshold)**을 적용하여 의미 있는 관계만 시각화합니다.

# %% [markdown]
# ## 07. 상관관계 심층 분석 (순위화 및 텍스트 요약)
# - **Centrality (중요도)**: 해당 장르/태그가 다른 항목과 얼마나 강하게 연결되는지 (최대 상관계수).
# - **Popularity (인기도)**: 인기 상위 100개 작품에서 얼마나 자주 등장하는지.
# - **Normalization (정규화)**: 두 지표의 스케일(0~1)을 맞춰 공정한 비교가 가능하게 함.

# %% [markdown]
# ## 10. 최종 요약 및 인사이트 도출
# - 요약: 어떤 (장르X태그)조합이 가장 대중적인가
#
#
# - 결론: 모델링이나 추천 시스템 구축 시, 이 **통합 스코어**를 활용할 수 있다.
#
#
# ![total_top20_main.png](attachment:total_top20_main.png)
# ![total_top15_genre.png](attachment:total_top15_genre.png)
# ![total_top15_tags.png](attachment:total_top15_tags.png)
